# %%
# Khai báo thư viện
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
# Đọc dữ liệu đầu vào
pathData = 'Data_Gestational_diabetes.csv'
# Dữ liệu đầu vào bao gồm 23 đặc trưng và đặc trưng thứ 23 là nhãn (0- Bình Thường, 1 - Mắc ĐTD, 2 - Nguy cơ cao)
columnName = ['Year_old','Occupatio','Education','gestational_age','Number_of_pregnancy','Para','Childbirth_history', 
              'Family_history','Height','Pre_gregnancy_weight','Current_Weight','Upper_blood_pressure', 
              'Lower_blood_pressure','Work_status','Work_performance','Nutrition', 'Sport_practice_day_per_month',
              'Sport_day_per_week', 'Sport_last_month', 'Glucose1','Glucose2','Glucose3','Conclude']
dataGD = pd.read_csv(pathData, names= columnName)
# Chuyển dữ liệu đầu vào sang dạng Ma trận
matrixData = dataGD.values
# Lấy ra tập đặc trưng huấn luyện
X = matrixData[1:,:-1]
# Lấy nhãn chẩn đoán: 0 - Bình Thường, 1 - Mắc ĐTD
y = matrixData[1:,-1]
dataGD.head()
# Out:
#    Year_old  Occupatio  Education  gestational_age  Number_of_pregnancy  Para  \
# 0  Year_old  Occupatio  Education  gestational_age  Number_of_pregnancy  Para
# 1        35          2          3               24                    2     2
# 2        39          0          0               24                    1     0
# 3        31          3          2               24                    1     0
# 4        31          0          1               24                    2     3
#
#    Childbirth_history  Family_history  Height  Pre_gregnancy_weight  ...  \
# 0  Childbirth_history  Family_history  Height  Pre_gregnancy_weight  ...
# 1                   1               0    1.54                    52  ...
# 2                   0               0    1.57                    41  ...
# 3                   0               0    1.58                    47  ...
# 4                   0               0     1.6                    45  ...
#
#    Work_status  Work_performance  Nutrition  Sport_practice_day_per_month  \
# 0  Work_status  Work_performance  Nutrition  Sport_practice_day_per_month
# 1            1                 0          2                             1
# 2            1                 0          2                             1
# 3            1                 0          2                             1
# 4            1                 0          2                             0
#
#    Sport_day_per_week  Sport_last_month  Glucose1  Glucose2  Glucose3  \
# 0  Sport_day_per_week  Sport_last_month  Glucose1  Glucose2  Glucose3
# 1                   2                30      4.37      9.68      7.52
# 2                   2                40      4.05      8.31      7.39
# 3                   3                15      4.43      8.06      6.75
# 4                   0                 0      4.58     10.36     10.38
#
#    Conclude
# 0  Conclude
# 1         2
# 2         0
# 3         0
# 4         1
#
# [5 rows x 23 columns]

# %%
# Thông tin bệnh nhân cần chẩn đoán
data_patients =[[28,0,1,27,2,3,0,0,1.6,47,52,120,80,1,0,2,0,0,0,4.1,4.68,2.97],
     [32,0,1,27,2,3,0,0,1.6,24,52,120,80,1,0,2,0,0,0,4.1,3.6,8.97], 
     [24,3,1,24,1,0,0,0,1.49,47,52,120,80,2,0,2,0,0,0,4.14,10.87,12.15]]

# Huấn luyện mô hình SVM
svm1 = svm.SVC(kernel='rbf', C=100000, gamma=1e-06)

svm1.fit(X,y)
# Dự đoán
svm_patient_pred  = svm1.predict(data_patients)
print('Diagnosis results SVM ',svm_patient_pred )
# Out:
# Diagnosis results SVM  ['0' '0' '1']
